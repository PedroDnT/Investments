# %% [markdown]
# # Enviroment

# %% [markdown]
# ## Install

# %%
install.packages("tidyverse")
# Out:
# Installing package into ‘/home/projects/R/x86_64-pc-linux-gnu-library/4.2’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sys’, ‘bit’, ‘ps’, ‘sass’, ‘cachem’, ‘memoise’, ‘rappdirs’, ‘askpass’, ‘bit64’, ‘processx’, ‘highr’, ‘yaml’, ‘xfun’, ‘bslib’, ‘jquerylib’, ‘tinytex’, ‘backports’, ‘assertthat’, ‘blob’, ‘DBI’, ‘data.table’, ‘gargle’, ‘curl’, ‘ids’, ‘rematch2’, ‘mime’, ‘openssl’, ‘timechange’, ‘rlang’, ‘clipr’, ‘vroom’, ‘tzdb’, ‘callr’, ‘fs’, ‘knitr’, ‘rmarkdown’, ‘selectr’, ‘stringi’, ‘broom’, ‘dbplyr’, ‘dtplyr’, ‘forcats’, ‘googledrive’, ‘googlesheets4’, ‘haven’, ‘httr’, ‘lubridate’, ‘modelr’, ‘readr’, ‘reprex’, ‘rstudioapi’, ‘rvest’, ‘stringr’, ‘tidyr’, ‘xml2’

# %% [markdown]
# ## Imports

# %%
library('tidyverse')
library('rvest')
library('dplyr')
library('BatchGetSymbols')
# Out:
# ── Attaching packages ───────────────────────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.1     ✔ stringr 1.4.1
# ✔ readr   2.1.3     ✔ forcats 0.5.2
# ── Conflicts ──────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘rvest’
#
#
# The following object is masked from ‘package:readr’:
#
#     guess_encoding

# %% [markdown]
# # Data

# %%
df <- read.csv('../data/carteira_ibov.csv', skip = 1, sep = ';')
# Out:
# Error in make.names(col.names, unique = TRUE): invalid multibyte string 1
# Traceback:
#
# 1. read.csv("../data/carteira_ibov.csv", skip = 1, sep = ";")
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 3. make.names(col.names, unique = TRUE)

# %%
df
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# ERROR while rich displaying an object: Error in gsub(chr, html_specials[[chr]], text, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
# ...

# %% [markdown]
# ## Head/ tail

# %%
head(df)
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”
# ERROR while rich displaying an object: Error in gsub(chr, html_specials[[chr]], text, fixed = TRUE): input string 1 is invalid in this locale
#
# Traceback:
# 1. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. doTryCatch(return(expr), name, parentenv, handler)
# 5. withCallingHandlers({
# ...

# %%
tail(df)
# Out:
#     date       X.ABEV3.SA X.ASAI3.SA X.AZUL4.SA X.B3SA3.SA X.BBAS3.SA
# 135 2021-09-10 16.10      18.13551   34.92      13.60231   28.80925
# 136 2021-09-13 16.35      18.62431   35.80      13.98644   29.44526
# 137 2021-09-14 16.44      18.28514   35.20      13.91749   29.23000
# 138 2021-09-15 16.02      18.54451   34.84      13.83870   29.00000
# 139 2021-09-16 16.13      19.11311   35.18      13.90764   29.47000
# 140 2021-09-17 15.74      18.95351   34.76      13.96674   28.94000
#     X.BBDC3.SA X.BBDC4.SA X.BBSE3.SA X.BEEF3.SA ⋯ X.TAEE11.SA X.TIMS3.SA
# 135 18.08288   20.92139   19.06      9.05       ⋯ 37.03       11.97213
# 136 18.38260   21.35101   19.57      9.17       ⋯ 37.53       12.22093
# 137 18.25272   21.21113   19.62      9.41       ⋯ 38.03       12.13136
# 138 18.11285   21.02130   19.22      9.60       ⋯ 37.48       11.99204
# 139 17.77318   20.75154   19.40      9.84       ⋯ 37.34       12.16122
# ...
