# %%
import pandas as pd

# %%
teste = pd.read_csv('../dados/ibov.csv')

# %%
teste
# Out:
#          Data  Preço ABEV3.SA  Preço ASAI3.SA  Preço AZUL4.SA  Preço B3SA3.SA  \
# 1  2021-07-01       17.200001       85.800003       43.959999       16.320000
# 2  2021-07-02       17.430000       86.000000       44.720001       16.420000
# 3  2021-07-05       17.940001       86.099998       44.349998       16.110001
# 4  2021-07-06       17.549999       85.699997       42.500000       15.920000
# 5  2021-07-07       17.770000       86.250000       42.669998       16.270000
# 6  2021-07-08       17.360001       86.199997       41.209999       16.150000
#
#    Preço BBAS3.SA  Preço BBDC3.SA  Preço BBDC4.SA  Preço BBSE3.SA  \
# 1       31.790001       21.140709       24.864641           23.23
# 2       32.139999       21.489992       25.460991           23.15
# 3       31.940001       21.230000       25.010000           22.91
# 4       31.459999       20.900000       24.700001           22.60
# 5       31.879999       21.059999       24.879999           22.85
# ...

# %%
teste.shape
# Out:
# (6, 83)
